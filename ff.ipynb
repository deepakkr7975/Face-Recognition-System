# %%
from sklearn.datasets import fetch_lfw_people
from sklearn.model_selection import train_test_split
from tf_keras.utils import to_categorical

# Download the full LFW dataset with all people included (no filtering)
lfw_people=fetch_lfw_people(min_faces_per_person=0,resize=0.4,color=False)

# Get the face images and labels
data=lfw_people.images # face images
labels=lfw_people.target # people
target_names= lfw_people.target_names #list of all person names

# %%
import pickle

# Save target names to a file
with open('target_names.pkl', 'wb') as f:
    pickle.dump(target_names, f)

# %%
# import cv2
# import numpy as np
# from tf_keras.models import load_model

# # Load the face recognition model
# model = load_model('face_recognition_model.h5')

# # Load target names (assuming you saved them separately during training)
# target_names = lfw_people.target_names

# # Start capturing video from the webcam
# cap = cv2.VideoCapture(0)

# # Define the face detector
# face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# while True:
#     # Capture frame-by-frame
#     ret, frame = cap.read()
    
#     # Convert the frame to grayscale (model expects grayscale images)
#     gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

#     # Detect faces in the frame
#     faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))
    
#     for (x, y, w, h) in faces:
#         # Extract the region of interest (the face)
#         face = gray[y:y+h, x:x+w]
        
#         # Resize the face to match the input size of the model (50x37, or the shape used during training)
#         face_resized = cv2.resize(face, (50, 37))
        
#         # Reshape the face to match the model input (add batch size and channel dimensions)
#         face_input = face_resized.reshape(1, 50, 37, 1)
        
#         # Normalize pixel values to [0, 1] (if needed)
#         face_input = face_input.astype('float32') / 255.0
        
#         # Predict the face using the model
#         predictions = model.predict(face_input)
#         predicted_class = np.argmax(predictions[0])
#         predicted_name = target_names[predicted_class]
        
#         # Draw a rectangle around the face and display the name
#         cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
#         cv2.putText(frame, predicted_name, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)
    
#     # Display the resulting frame
#     cv2.imshow('Face Recognition', frame)

#     # Break the loop if 'q' is pressed
#     if cv2.waitKey(1) & 0xFF == ord('q'):
#         break

# # Release the capture and close all OpenCV windows
# cap.release()
# cv2.destroyAllWindows()

# %%
# import cv2
# import numpy as np
# from tf_keras.models import load_model
# import pickle

# # Load the pre-trained face recognition model
# model = load_model('face_recognition_model.h5')

# # Load the target names (assuming you saved them separately using pickle)
# with open('target_names.pkl', 'rb') as f:
#     target_names = pickle.load(f)

# # Load the Haar cascade for face detection
# face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# # Start capturing video from the webcam
# cap = cv2.VideoCapture(0)

# # Check if the webcam is successfully opened
# if not cap.isOpened():
#     print("Error: Could not open video stream.")
#     exit()

# while True:
#     # Capture frame-by-frame from the webcam
#     ret, frame = cap.read()

#     # Check if a frame was successfully captured
#     if not ret:
#         print("Failed to grab frame.")
#         break

#     # Check if the frame is empty
#     if frame is None:
#         print("Received an empty frame.")
#         continue

#     # Convert the frame to grayscale as face detection typically works on grayscale images
#     gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

#     # Detect faces in the grayscale frame
#     faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

#     for (x, y, w, h) in faces:
#         # Draw a rectangle around the face
#         cv2.rectangle(frame, (x, y), (x + w, y + h), (255, 0, 0), 2)

#         # Extract the face region from the grayscale image and resize it to match the model's input size
#         face = gray[y:y + h, x:x + w]
#         face_resized = cv2.resize(face, (224, 224))  # Resize to the input size your model expects

#         # Normalize pixel values (if required by your model)
#         face_resized = face_resized.astype('float32') / 255.0
#         face_resized = np.expand_dims(face_resized, axis=0)  # Add batch dimension

#         # Make a prediction
#         prediction = model.predict(face_resized)
#         predicted_class = np.argmax(prediction)

#         # Get the predicted class label
#         predicted_label = target_names[predicted_class]

#         # Display the label above the face rectangle
#         cv2.putText(frame, predicted_label, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (255, 255, 255), 2)

#     # Display the resulting frame with detected faces and labels
#     cv2.imshow('Face Recognition', frame)

#     # Break the loop if the 'q' key is pressed
#     if cv2.waitKey(1) & 0xFF == ord('q'):
#         break

# # Release the webcam and close windows
# cap.release()
# cv2.destroyAllWindows()

# %%
# import cv2
# import numpy as np
# from tf_keras.models import load_model

# # Load the face recognition model
# model = load_model('face_recognition_model.h5')

# # Initialize the face detector (Haar Cascade)
# face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# # Start capturing video from the webcam
# cap = cv2.VideoCapture(0)

# while True:
#     # Capture frame-by-frame
#     ret, frame = cap.read()
    
#     if not ret:
#         print("Failed to grab frame")
#         break

#     # Convert the frame to grayscale
#     gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

#     # Detect faces in the frame
#     faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

#     # Loop through each detected face
#     for (x, y, w, h) in faces:
#         # Extract the face region of interest (ROI)
#         gray_face = gray[y:y+h, x:x+w]

#         # Resize the face to the expected size of the model (37x50)
#         face_resized = cv2.resize(gray_face, (37, 50))  # Resize to match the model's expected input size

#         # Normalize pixel values (optional but often helpful)
#         face_resized = face_resized / 255.0

#         # Expand dimensions to fit the model's input shape (None, 50, 37, 1)
#         face_resized = np.expand_dims(face_resized, axis=-1)  # Add channel dimension (grayscale: 1 channel)
#         face_resized = np.expand_dims(face_resized, axis=0)   # Add batch dimension

#         # Make a prediction
#         prediction = model.predict(face_resized)
#         predicted_class = np.argmax(prediction)

#         # Get the predicted class label (assuming you have `target_names` loaded)
#         label = target_names[predicted_class]

#         # Draw the label and rectangle around the face
#         cv2.putText(frame, label, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (255, 0, 0), 2)

# %%
import cv2
import numpy as np
from tf_keras.models import load_model
import pickle

# Load the face recognition model
model = load_model('face_recognition_model.h5')

# Load target names (assuming they were saved during training)
with open('target_names.pkl', 'rb') as f:
    target_names = pickle.load(f)

# Initialize the face detector (Haar Cascade)
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# Start capturing video from the webcam
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

while True:
    # Capture frame-by-frame
    ret, frame = cap.read()
    
    if not ret:
        print("Failed to grab frame")
        break

    # Convert the frame to grayscale
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect faces in the frame
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

    # Loop through each detected face
    for (x, y, w, h) in faces:
        # Extract the face region of interest (ROI)
        gray_face = gray[y:y+h, x:x+w]

        # Resize the face to the expected size of the model (37x50)
        face_resized = cv2.resize(gray_face, (37, 50))  # Resize to match the model's expected input size

        # Normalize pixel values
        face_resized = face_resized / 255.0

        # Expand dimensions to fit the model's input shape (None, 50, 37, 1)
        face_resized = np.expand_dims(face_resized, axis=-1)  # Add channel dimension (grayscale: 1 channel)
        face_resized = np.expand_dims(face_resized, axis=0)   # Add batch dimension

        # Make a prediction
        prediction = model.predict(face_resized)
        predicted_class = np.argmax(prediction)

        # Get the predicted class label
        label = target_names[predicted_class]

        # Draw the label and rectangle around the face
        cv2.putText(frame, label, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (255, 0, 0), 2)
        cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 0, 0), 2)

    # Display the resulting frame
    cv2.imshow('Face Recognition', frame)

    # Quit when 'q' key is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the capture and close windows
cap.release()
cv2.destroyAllWindows()
